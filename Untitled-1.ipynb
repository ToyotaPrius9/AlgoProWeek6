# %%
inventory = {
 'gold' : 500,
 'pouch' : ['flint', 'twine', 'gemstone'],
 'backpack' : ['xylophone','dagger', 'bedroll','bread loaf']
}


inventory['pocket'] = ['seashell'], ['strange berry'], ['lint']
inventory['backpack'].sort()
inventory['backpack'].remove('dagger')
inventory['gold']+=50
# Out:
# {'gold': 550, 'pouch': ['flint', 'twine', 'gemstone'], 'backpack': ['bedroll', 'bread loaf', 'xylophone'], 'pocket': (['seashell'], ['strange berry'], ['lint'])}

# %%
prices = {}

prices["banana"]= 4
prices["apple"]= 2
prices["orange"]= 1.5
prices["pear"]=3

stock = {
"banana": 12,
"apple": 0,
"orange": 3,
"pear": 4
}

mao = [],

for i in mao:
        total = 0
        willtolive=0
        #loop 1
        while willtolive !=4:
            print( list(prices.keys())[willtolive],'\nprice:', ( list(prices.values())[willtolive] ),('\nstock:'), list(stock.values())[willtolive], ('\n') )
            willtolive += 1
        
        #loop2
        willtofly = 0
        while willtofly != 4:
             print(( list(prices.values())[willtofly] ) * list(stock.values())[willtofly])
             total += ( list(prices.values())[willtofly] ) * list(stock.values())[willtofly]
             willtofly += 1 
       
        




print('\n''\n',total)
# Out:
# banana
# price: 4
# stock: 12
#
# apple
# price: 2
# stock: 0
#
# orange
# price: 1.5
# stock: 3
#
# pear
# price: 3
# stock: 4
#
# 48
# 0
# 4.5
# 12
#
#
#  64.5

# %%
groceries = ["banana"],["orange"], ["apple"]

stock = {
 "banana": 6,
 "apple": 0,
 "orange": 32,
 "pear": 15
}
prices = {
 "banana": 4,
 "apple": 2,
 "orange": 1.5,
 "pear": 3
}


def compute_bill(food):
    def compute_bill(food):
        total=0
        for i in food:

            if stock[i]>0:
                total=total+prices[i]
            stock[i]=stock[i]-1
        print("Total:", total)
compute_bill(groceries)

# %%
eren = {
 "name": "Eren",
 "homework": [90.0,97.0,75.0,92.0],
 "quizzes": [88.0,40.0,94.0],
 "tests": [75.0,90.0]
}

mikasa = {
"name": "Mikasa",
"homework": [100.0, 92.0, 98.0, 100.0],
"quizzes": [82.0, 83.0, 91.0],
"tests": [89.0, 97.0]
}

armin = {
"name": "Armin",
"homework": [0.0, 87.0, 75.0, 22.0],
"quizzes": [0.0, 75.0, 78.0],
"tests": [100.0, 100.0]
}

students=[armin,mikasa, eren]


for i in students:
    print("Name:", i["name"], '\n', 
    "Homework:", i["homework"], '\n', 
    "Quizzes:", i["quizzes"], '\n', 
    "Tests:", i["tests"])

def average(numbers):

    total=sum(numbers)
    total=float(sum((numbers))) 
    avg=total/len(numbers)
    return avg


def get_average(student)->dict:
    homework =  average(student["homework"])
    quizzes = average(student["quizzes"])
    tests = average(student["tests"])
    homework_avg = float(homework) * 0.1
    quizzes_avg = float(quizzes) * 0.3
    tests_avg = float(tests) * 0.6
    sum_grade = (homework_avg + quizzes_avg + tests_avg)
    return sum_grade


def get_letter_grade(score):
    if score>90:
        return "A"
    elif score>80:
        return "B"
    elif score>70:
        return "C"
    elif score>60:
        return "D"
    else:
        return "F"


get_letter_grade(get_average(eren))

def get_class_average(students)->list:
    results = []
    for student in students:
        results.append(get_average(student))

    return(average(results))


print('\nCLASS AVERAGE IN NUMBERS IS:',get_class_average(students))
print('\n CLASS AVERAGE IS:', get_letter_grade(get_class_average([armin,mikasa,eren])))
# Out:
# Name: Armin
#  Homework: [0.0, 87.0, 75.0, 22.0]
#  Quizzes: [0.0, 75.0, 78.0]
#  Tests: [100.0, 100.0]
# Name: Mikasa
#  Homework: [100.0, 92.0, 98.0, 100.0]
#  Quizzes: [82.0, 83.0, 91.0]
#  Tests: [89.0, 97.0]
# Name: Eren
#  Homework: [90.0, 97.0, 75.0, 92.0]
#  Quizzes: [88.0, 40.0, 94.0]
#  Tests: [75.0, 90.0]
#
# CLASS AVERAGE IN NUMBERS IS: 83.86666666666667
#
#  CLASS AVERAGE IS: B
